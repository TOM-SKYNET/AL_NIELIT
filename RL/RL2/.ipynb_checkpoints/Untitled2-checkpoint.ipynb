# %%
import gym
import numpy as np

Q = np.zeros([500,6])
gamma = .801

env = gym.make("Taxi-v2")

for episode in range(1,1000):
    state = env.reset()
    cnt = 1
    reward = 0
    while reward != 20:
        action = np.argmax(Q[state])
        state2, reward,done,info = env.step(action)
        Q[state,action] = reward + gamma * np.max(Q[state2])
        state = state2
        cnt = cnt + 1

        if episode % 50 == 0:
            print("Needed " + str(cnt) + " moves to reach the final state during episode " + str(episode))
# Out:
# Needed 2 moves to reach the final state during episode 50
# Needed 3 moves to reach the final state during episode 50
# Needed 4 moves to reach the final state during episode 50
# Needed 5 moves to reach the final state during episode 50
# Needed 6 moves to reach the final state during episode 50
# Needed 7 moves to reach the final state during episode 50
# Needed 8 moves to reach the final state during episode 50
# Needed 9 moves to reach the final state during episode 50
# Needed 10 moves to reach the final state during episode 50
# Needed 11 moves to reach the final state during episode 50
# Needed 12 moves to reach the final state during episode 50
# Needed 13 moves to reach the final state during episode 50
# Needed 14 moves to reach the final state during episode 50
# Needed 15 moves to reach the final state during episode 50
# Needed 16 moves to reach the final state during episode 50
# Needed 17 moves to reach the final state during episode 50
# Needed 18 moves to reach the final state during episode 50
# Needed 19 moves to reach the final state during episode 50
# Needed 20 moves to reach the final state during episode 50
# Needed 21 moves to reach the final state during episode 50
# Needed 22 moves to reach the final state during episode 50
# Needed 23 moves to reach the final state during episode 50
# Needed 24 moves to reach the final state during episode 50
# Needed 25 moves to reach the final state during episode 50
# Needed 26 moves to reach the final state during episode 50
# Needed 2 moves to reach the final state during episode 100
# Needed 3 moves to reach the final state during episode 100
# Needed 4 moves to reach the final state during episode 100
# Needed 5 moves to reach the final state during episode 100
# Needed 6 moves to reach the final state during episode 100
# Needed 7 moves to reach the final state during episode 100
# Needed 8 moves to reach the final state during episode 100
# Needed 9 moves to reach the final state during episode 100
# Needed 10 moves to reach the final state during episode 100
# Needed 11 moves to reach the final state during episode 100
# Needed 12 moves to reach the final state during episode 100
# Needed 13 moves to reach the final state during episode 100
# Needed 14 moves to reach the final state during episode 100
# Needed 15 moves to reach the final state during episode 100
# Needed 16 moves to reach the final state during episode 100
# Needed 17 moves to reach the final state during episode 100
# Needed 18 moves to reach the final state during episode 100
# Needed 19 moves to reach the final state during episode 100
# Needed 20 moves to reach the final state during episode 100
# Needed 21 moves to reach the final state during episode 100
# Needed 22 moves to reach the final state during episode 100
# Needed 23 moves to reach the final state during episode 100
# Needed 24 moves to reach the final state during episode 100
# Needed 25 moves to reach the final state during episode 100
# Needed 26 moves to reach the final state during episode 100
# Needed 27 moves to reach the final state during episode 100
# Needed 28 moves to reach the final state during episode 100
# Needed 29 moves to reach the final state during episode 100
# Needed 30 moves to reach the final state during episode 100
# Needed 31 moves to reach the final state during episode 100
# Needed 32 moves to reach the final state during episode 100
# Needed 33 moves to reach the final state during episode 100
# Needed 34 moves to reach the final state during episode 100
# Needed 35 moves to reach the final state during episode 100
# Needed 36 moves to reach the final state during episode 100
# Needed 37 moves to reach the final state during episode 100
# Needed 38 moves to reach the final state during episode 100
# Needed 39 moves to reach the final state during episode 100
# Needed 40 moves to reach the final state during episode 100
# Needed 41 moves to reach the final state during episode 100
# Needed 42 moves to reach the final state during episode 100
# Needed 43 moves to reach the final state during episode 100
# Needed 44 moves to reach the final state during episode 100
# Needed 45 moves to reach the final state during episode 100
# Needed 46 moves to reach the final state during episode 100
# Needed 47 moves to reach the final state during episode 100
# Needed 48 moves to reach the final state during episode 100
# Needed 49 moves to reach the final state during episode 100
# Needed 50 moves to reach the final state during episode 100
# Needed 51 moves to reach the final state during episode 100
# Needed 52 moves to reach the final state during episode 100
# Needed 53 moves to reach the final state during episode 100
# Needed 54 moves to reach the final state during episode 100
# Needed 55 moves to reach the final state during episode 100
# Needed 56 moves to reach the final state during episode 100
# Needed 57 moves to reach the final state during episode 100
# Needed 58 moves to reach the final state during episode 100
# Needed 59 moves to reach the final state during episode 100
# Needed 60 moves to reach the final state during episode 100
# Needed 61 moves to reach the final state during episode 100
# Needed 62 moves to reach the final state during episode 100
# Needed 63 moves to reach the final state during episode 100
# Needed 64 moves to reach the final state during episode 100
# Needed 65 moves to reach the final state during episode 100
# Needed 66 moves to reach the final state during episode 100
# Needed 67 moves to reach the final state during episode 100
# Needed 68 moves to reach the final state during episode 100
# Needed 69 moves to reach the final state during episode 100
# Needed 70 moves to reach the final state during episode 100
# Needed 71 moves to reach the final state during episode 100
# Needed 72 moves to reach the final state during episode 100
# Needed 73 moves to reach the final state during episode 100
# Needed 74 moves to reach the final state during episode 100
# Needed 75 moves to reach the final state during episode 100
# Needed 76 moves to reach the final state during episode 100
# Needed 77 moves to reach the final state during episode 100
# Needed 78 moves to reach the final state during episode 100
# Needed 79 moves to reach the final state during episode 100
# Needed 80 moves to reach the final state during episode 100
# Needed 81 moves to reach the final state during episode 100
# Needed 82 moves to reach the final state during episode 100
# Needed 83 moves to reach the final state during episode 100
# Needed 84 moves to reach the final state during episode 100
# Needed 85 moves to reach the final state during episode 100
# Needed 86 moves to reach the final state during episode 100
# Needed 87 moves to reach the final state during episode 100
# Needed 88 moves to reach the final state during episode 100
# Needed 89 moves to reach the final state during episode 100
# Needed 90 moves to reach the final state during episode 100
# Needed 91 moves to reach the final state during episode 100
# Needed 92 moves to reach the final state during episode 100
# Needed 93 moves to reach the final state during episode 100
# Needed 94 moves to reach the final state during episode 100
# Needed 95 moves to reach the final state during episode 100
# Needed 96 moves to reach the final state during episode 100
# Needed 97 moves to reach the final state during episode 100
# Needed 98 moves to reach the final state during episode 100
# Needed 99 moves to reach the final state during episode 100
# Needed 100 moves to reach the final state during episode 100
# Needed 101 moves to reach the final state during episode 100
# Needed 102 moves to reach the final state during episode 100
# Needed 103 moves to reach the final state during episode 100
# Needed 104 moves to reach the final state during episode 100
# Needed 105 moves to reach the final state during episode 100
# Needed 106 moves to reach the final state during episode 100
# Needed 107 moves to reach the final state during episode 100
# Needed 108 moves to reach the final state during episode 100
# Needed 109 moves to reach the final state during episode 100
# Needed 110 moves to reach the final state during episode 100
# Needed 111 moves to reach the final state during episode 100
# Needed 112 moves to reach the final state during episode 100
# Needed 113 moves to reach the final state during episode 100
# Needed 114 moves to reach the final state during episode 100
# Needed 115 moves to reach the final state during episode 100
# Needed 2 moves to reach the final state during episode 150
# Needed 3 moves to reach the final state during episode 150
# Needed 4 moves to reach the final state during episode 150
# Needed 5 moves to reach the final state during episode 150
# Needed 6 moves to reach the final state during episode 150
# Needed 7 moves to reach the final state during episode 150
# Needed 8 moves to reach the final state during episode 150
# Needed 9 moves to reach the final state during episode 150
# Needed 10 moves to reach the final state during episode 150
# Needed 11 moves to reach the final state during episode 150
# Needed 2 moves to reach the final state during episode 200
# Needed 3 moves to reach the final state during episode 200
# Needed 4 moves to reach the final state during episode 200
# Needed 5 moves to reach the final state during episode 200
# Needed 6 moves to reach the final state during episode 200
# Needed 7 moves to reach the final state during episode 200
# Needed 8 moves to reach the final state during episode 200
# Needed 9 moves to reach the final state during episode 200
# Needed 10 moves to reach the final state during episode 200
# Needed 11 moves to reach the final state during episode 200
# Needed 12 moves to reach the final state during episode 200
# Needed 2 moves to reach the final state during episode 250
# Needed 3 moves to reach the final state during episode 250
# Needed 4 moves to reach the final state during episode 250
# Needed 5 moves to reach the final state during episode 250
# Needed 6 moves to reach the final state during episode 250
# Needed 7 moves to reach the final state during episode 250
# Needed 8 moves to reach the final state during episode 250
# Needed 9 moves to reach the final state during episode 250
# Needed 10 moves to reach the final state during episode 250
# Needed 11 moves to reach the final state during episode 250
# Needed 12 moves to reach the final state during episode 250
# Needed 13 moves to reach the final state during episode 250
# Needed 14 moves to reach the final state during episode 250
# Needed 2 moves to reach the final state during episode 300
# Needed 3 moves to reach the final state during episode 300
# Needed 4 moves to reach the final state during episode 300
# Needed 5 moves to reach the final state during episode 300
# Needed 6 moves to reach the final state during episode 300
# Needed 7 moves to reach the final state during episode 300
# Needed 8 moves to reach the final state during episode 300
# Needed 9 moves to reach the final state during episode 300
# Needed 10 moves to reach the final state during episode 300
# Needed 11 moves to reach the final state during episode 300
# Needed 12 moves to reach the final state during episode 300
# Needed 13 moves to reach the final state during episode 300
# Needed 14 moves to reach the final state during episode 300
# Needed 15 moves to reach the final state during episode 300
# Needed 16 moves to reach the final state during episode 300
# Needed 17 moves to reach the final state during episode 300
# Needed 18 moves to reach the final state during episode 300
# Needed 2 moves to reach the final state during episode 350
# Needed 3 moves to reach the final state during episode 350
# Needed 4 moves to reach the final state during episode 350
# Needed 5 moves to reach the final state during episode 350
# Needed 6 moves to reach the final state during episode 350
# Needed 7 moves to reach the final state during episode 350
# Needed 8 moves to reach the final state during episode 350
# Needed 9 moves to reach the final state during episode 350
# Needed 10 moves to reach the final state during episode 350
# Needed 11 moves to reach the final state during episode 350
# Needed 12 moves to reach the final state during episode 350
# Needed 13 moves to reach the final state during episode 350
# Needed 14 moves to reach the final state during episode 350
# Needed 15 moves to reach the final state during episode 350
# Needed 16 moves to reach the final state during episode 350
# Needed 17 moves to reach the final state during episode 350
# Needed 2 moves to reach the final state during episode 400
# Needed 3 moves to reach the final state during episode 400
# Needed 4 moves to reach the final state during episode 400
# Needed 5 moves to reach the final state during episode 400
# Needed 6 moves to reach the final state during episode 400
# Needed 7 moves to reach the final state during episode 400
# Needed 8 moves to reach the final state during episode 400
# Needed 9 moves to reach the final state during episode 400
# Needed 10 moves to reach the final state during episode 400
# Needed 11 moves to reach the final state during episode 400
# Needed 12 moves to reach the final state during episode 400
# Needed 13 moves to reach the final state during episode 400
# Needed 14 moves to reach the final state during episode 400
# Needed 15 moves to reach the final state during episode 400
# Needed 2 moves to reach the final state during episode 450
# Needed 3 moves to reach the final state during episode 450
# Needed 4 moves to reach the final state during episode 450
# Needed 5 moves to reach the final state during episode 450
# Needed 6 moves to reach the final state during episode 450
# Needed 7 moves to reach the final state during episode 450
# Needed 8 moves to reach the final state during episode 450
# Needed 9 moves to reach the final state during episode 450
# Needed 10 moves to reach the final state during episode 450
# Needed 2 moves to reach the final state during episode 500
# Needed 3 moves to reach the final state during episode 500
# Needed 4 moves to reach the final state during episode 500
# Needed 5 moves to reach the final state during episode 500
# Needed 6 moves to reach the final state during episode 500
# Needed 7 moves to reach the final state during episode 500
# Needed 8 moves to reach the final state during episode 500
# Needed 9 moves to reach the final state during episode 500
# Needed 10 moves to reach the final state during episode 500
# Needed 11 moves to reach the final state during episode 500
# Needed 12 moves to reach the final state during episode 500
# Needed 13 moves to reach the final state during episode 500
# Needed 14 moves to reach the final state during episode 500
# Needed 15 moves to reach the final state during episode 500
# Needed 2 moves to reach the final state during episode 550
# Needed 3 moves to reach the final state during episode 550
# Needed 4 moves to reach the final state during episode 550
# Needed 5 moves to reach the final state during episode 550
# Needed 6 moves to reach the final state during episode 550
# Needed 7 moves to reach the final state during episode 550
# Needed 8 moves to reach the final state during episode 550
# Needed 9 moves to reach the final state during episode 550
# Needed 10 moves to reach the final state during episode 550
# Needed 11 moves to reach the final state during episode 550
# Needed 12 moves to reach the final state during episode 550
# Needed 13 moves to reach the final state during episode 550
# Needed 14 moves to reach the final state during episode 550
# Needed 15 moves to reach the final state during episode 550
# Needed 16 moves to reach the final state during episode 550
# Needed 2 moves to reach the final state during episode 600
# Needed 3 moves to reach the final state during episode 600
# Needed 4 moves to reach the final state during episode 600
# Needed 5 moves to reach the final state during episode 600
# Needed 6 moves to reach the final state during episode 600
# Needed 7 moves to reach the final state during episode 600
# Needed 8 moves to reach the final state during episode 600
# Needed 9 moves to reach the final state during episode 600
# Needed 2 moves to reach the final state during episode 650
# Needed 3 moves to reach the final state during episode 650
# Needed 4 moves to reach the final state during episode 650
# Needed 5 moves to reach the final state during episode 650
# Needed 6 moves to reach the final state during episode 650
# Needed 7 moves to reach the final state during episode 650
# Needed 8 moves to reach the final state during episode 650
# Needed 9 moves to reach the final state during episode 650
# Needed 10 moves to reach the final state during episode 650
# Needed 11 moves to reach the final state during episode 650
# Needed 12 moves to reach the final state during episode 650
# Needed 13 moves to reach the final state during episode 650
# Needed 14 moves to reach the final state during episode 650
# Needed 2 moves to reach the final state during episode 700
# Needed 3 moves to reach the final state during episode 700
# Needed 4 moves to reach the final state during episode 700
# Needed 5 moves to reach the final state during episode 700
# Needed 6 moves to reach the final state during episode 700
# Needed 7 moves to reach the final state during episode 700
# Needed 8 moves to reach the final state during episode 700
# Needed 9 moves to reach the final state during episode 700
# Needed 10 moves to reach the final state during episode 700
# Needed 11 moves to reach the final state during episode 700
# Needed 12 moves to reach the final state during episode 700
# Needed 13 moves to reach the final state during episode 700
# Needed 14 moves to reach the final state during episode 700
# Needed 2 moves to reach the final state during episode 750
# Needed 3 moves to reach the final state during episode 750
# Needed 4 moves to reach the final state during episode 750
# Needed 5 moves to reach the final state during episode 750
# Needed 6 moves to reach the final state during episode 750
# Needed 7 moves to reach the final state during episode 750
# Needed 8 moves to reach the final state during episode 750
# Needed 9 moves to reach the final state during episode 750
# Needed 10 moves to reach the final state during episode 750
# Needed 11 moves to reach the final state during episode 750
# Needed 12 moves to reach the final state during episode 750
# Needed 13 moves to reach the final state during episode 750
# Needed 14 moves to reach the final state during episode 750
# Needed 15 moves to reach the final state during episode 750
# Needed 2 moves to reach the final state during episode 800
# Needed 3 moves to reach the final state during episode 800
# Needed 4 moves to reach the final state during episode 800
# Needed 5 moves to reach the final state during episode 800
# Needed 6 moves to reach the final state during episode 800
# Needed 7 moves to reach the final state during episode 800
# Needed 8 moves to reach the final state during episode 800
# Needed 9 moves to reach the final state during episode 800
# Needed 10 moves to reach the final state during episode 800
# Needed 11 moves to reach the final state during episode 800
# Needed 12 moves to reach the final state during episode 800
# Needed 13 moves to reach the final state during episode 800
# Needed 14 moves to reach the final state during episode 800
# Needed 15 moves to reach the final state during episode 800
# Needed 2 moves to reach the final state during episode 850
# Needed 3 moves to reach the final state during episode 850
# Needed 4 moves to reach the final state during episode 850
# Needed 5 moves to reach the final state during episode 850
# Needed 6 moves to reach the final state during episode 850
# Needed 7 moves to reach the final state during episode 850
# Needed 8 moves to reach the final state during episode 850
# Needed 9 moves to reach the final state during episode 850
# Needed 10 moves to reach the final state during episode 850
# Needed 11 moves to reach the final state during episode 850
# Needed 12 moves to reach the final state during episode 850
# Needed 2 moves to reach the final state during episode 900
# Needed 3 moves to reach the final state during episode 900
# Needed 4 moves to reach the final state during episode 900
# Needed 5 moves to reach the final state during episode 900
# Needed 6 moves to reach the final state during episode 900
# Needed 7 moves to reach the final state during episode 900
# Needed 8 moves to reach the final state during episode 900
# Needed 9 moves to reach the final state during episode 900
# Needed 10 moves to reach the final state during episode 900
# Needed 11 moves to reach the final state during episode 900
# Needed 12 moves to reach the final state during episode 900
# Needed 13 moves to reach the final state during episode 900
# Needed 2 moves to reach the final state during episode 950
# Needed 3 moves to reach the final state during episode 950
# Needed 4 moves to reach the final state during episode 950
# Needed 5 moves to reach the final state during episode 950
# Needed 6 moves to reach the final state during episode 950
# Needed 7 moves to reach the final state during episode 950
# Needed 8 moves to reach the final state during episode 950
# Needed 9 moves to reach the final state during episode 950
# Needed 10 moves to reach the final state during episode 950
# Needed 11 moves to reach the final state during episode 950
# Needed 12 moves to reach the final state during episode 950
